# %% [markdown]
# <a href="https://colab.research.google.com/github/montifar/machine-learning-prog/blob/main/AI_machine_learning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # my machine learning

# %% [markdown]
# data library

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, r2_score
import matplotlib.pyplot as plt


data = {
    "brand": ["Honda", "Yamaha", "Suzuki", "Kawasaki", "Honda", "Yamaha", "Suzuki", "Honda"],
    "engine_cc": [150, 155, 125, 400, 160, 155, 200, 150],
    "year": [2020, 2021, 2018, 2019, 2022, 2020, 2021, 2017],
    "mileage_km": [8000, 5000, 12000, 7000, 3000, 9000, 6000, 14000],
    "price": [65000, 72000, 45000, 200000, 78000, 70000, 90000, 40000]
}

df = pd.DataFrame(data)
print("Dataset:")
display(df)


df_encoded = pd.get_dummies(df, columns=["brand"], drop_first=True)


X = df_encoded.drop("price", axis=1)
y = df_encoded["price"]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)


model = LinearRegression()
model.fit(X_train, y_train)


predictions = model.predict(X_test)

print("\nMODEL PERFORMANCE")
print("MAE:", mean_absolute_error(y_test, predictions))
print("R² Score:", r2_score(y_test, predictions))


plt.scatter(y_test, predictions)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("Motorcycle Price Prediction")
plt.grid(True)
plt.show()


new_motor = {
    "engine_cc": 155,
    "year": 2022,
    "mileage_km": 5000,
    "brand_Kawasaki": 0,
    "brand_Suzuki": 0,
    "brand_Yamaha": 1,
}

new_df = pd.DataFrame([new_motor])
predicted_price = model.predict(new_df)[0]

print("\nPredicted price for sample motorcycle:", int(predicted_price))
# Out:
# Dataset:
#       brand  engine_cc  year  mileage_km   price
# 0     Honda        150  2020        8000   65000
# 1    Yamaha        155  2021        5000   72000
# 2    Suzuki        125  2018       12000   45000
# 3  Kawasaki        400  2019        7000  200000
# 4     Honda        160  2022        3000   78000
# 5    Yamaha        155  2020        9000   70000
# 6    Suzuki        200  2021        6000   90000
# 7     Honda        150  2017       14000   40000
# MODEL PERFORMANCE
# MAE: 12913.49877491345
# R² Score: -31.21719670065238
# Predicted price for sample motorcycle: 52379

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=df)
# Out:
# https://docs.google.com/spreadsheets/d/1Mq2cOa0UVrtPx-0KgFPAoFNlodDWDv5op0dGtq009yk/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1Mq2cOa0UVrtPx-0KgFPAoFNlodDWDv5op0dGtq009yk/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
